# %%
import pickle
from pathlib import Path
import networkx as nx
from pyvis.network import Network


BASE_DIR = Path.cwd()
DATA_DIR = BASE_DIR / "../data"
DOCS_DIR = BASE_DIR / "../docs"
DOCS_DIR.mkdir(exist_ok=True)
print("Output directory:", DOCS_DIR)
with open(DATA_DIR / "airport_network.gpickle", "rb") as f:
    G = pickle.load(f)
print(G)
print("Nodes:", G.number_of_nodes())
print("Edges:", G.number_of_edges())
net = Network(height="800px", width="100%", bgcolor="#ffffff",font_color="black",
 notebook=False,cdn_resources="remote")
net.barnes_hut(gravity=-80000,central_gravity=0.3,spring_length=120,
spring_strength=0.01,damping=0.09,overlap=0)
for node in G.nodes():
    degree = G.degree(node)
    city = G.nodes[node].get("city", "")
    country = G.nodes[node].get("country", "")
    community = G.nodes[node].get("community", 0)
    title = f"""
    <b>{node}</b><br>
    {city}, {country}<br>
    Degree: {degree}<br>
    Community: {community}
    """

    net.add_node(node,label=node,title=title,
size=max(5, degree * 0.3), color=int(community))
edge_count = 0
for u, v in G.edges():
    net.add_edge(u, v, value=1)
    edge_count += 1
    if edge_count % 5000 == 0:
        print(f"Edges added: {edge_count}")
print("Total edges:", edge_count)
output_file = DOCS_DIR / "index.html"
net.write_html( str(output_file),open_browser=False, notebook=False)
print(output_file)
# Out:
# Output directory: /home/mzhc13/master/complex-networks-airports/notebooks/../docs
# Graph with 3397 nodes and 19231 edges
# Nodes: 3397
# Edges: 19231
# Edges added: 5000
# Edges added: 10000
# Edges added: 15000
# Total edges: 19231
# /home/mzhc13/master/complex-networks-airports/notebooks/../docs/index.html
